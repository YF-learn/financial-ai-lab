# %% [markdown]
# ## 4.1 统计模型

# %% [markdown]
# ## 4.2 建模方法

# %% [markdown]
# ## 4.3 数据表示与模型名称

# %% [markdown]
# ## 4.4 最大似然估计

# %% [markdown]
# ## 4.5 最小化损失（最小二乘估计）

# %% [markdown]
# ## 4.6 预测精度的评估与变量选择
